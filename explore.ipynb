# %% [markdown]
# # Explore

# %% [markdown]
# Import Python tools

# %%
import geopandas as gpd
import altair as alt

# %% [markdown]
# Read in the combined file

# %%
gdf = gpd.read_file("food-inspections.geojson")

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 39276 entries, 0 to 39275
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   OBJECTID                39276 non-null  int32
#  1   HealthFacilityIDNumber  39276 non-null  object
#  2   FacilityCategory        39276 non-null  object
#  3   BusinessName            39276 non-null  object
#  4   RiskLevel               39276 non-null  object
#  5   FullAddress             39263 non-null  object
#  6   AddrNum                 39263 non-null  float64
#  7   AddrNumSuffix           34 non-null     object
#  8   StreetName              39263 non-null  object
#  9   StreetType              38331 non-null  object
#  10  PostDir                 27746 non-null  object
#  11  Unit                    4031 non-null   object
#  12  City                    39263 non-null  object
#  13  State                   39263 non-null  object
# ...

# %%
gdf.head()
# Out:
#    OBJECTID HealthFacilityIDNumber   FacilityCategory  \
# 0         1               LIC38596  BOARD AND LODGING
# 1         2               LIC38596  BOARD AND LODGING
# 2         3               LIC49742            GROCERY
# 3         4               LIC49743         RESTAURANT
# 4         5               LIC49743         RESTAURANT
#
#                   BusinessName RiskLevel         FullAddress  AddrNum  \
# 0  TAU OF APLHA OMICRON PI INC         1      1121 5TH ST SE   1121.0
# 1  TAU OF APLHA OMICRON PI INC         1      1121 5TH ST SE   1121.0
# 2           SUPERAMERICA #4034         3  2200 LYNDALE AVE S   2200.0
# 3           SUPERAMERICA #4034         2  2200 LYNDALE AVE S   2200.0
# 4           SUPERAMERICA #4034         2  2200 LYNDALE AVE S   2200.0
#
#   AddrNumSuffix StreetName StreetType  ... InspectionScore ViolationIDNumber  \
# 0          None        5TH         ST  ...             100                -1
# ...
